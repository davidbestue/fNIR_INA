# %% [markdown]
# ### Import libraries

# %%
from scipy.stats import ttest_ind
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import pandas as pd
import itertools
import seaborn as sns
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

# %% [markdown]
# ### Change directory to the pickle and read it

# %%
#roots 
root_data =  'C:\\Users\\David\\Google Drive\\Alicante'
root_analysis = 'C:\\Users\\David\\Dropbox\\ALICANTE\\plots_fnir'

os.chdir( root_data)
f=open("data_fnir.pickle","rb")
data=np.array(pickle.load(f, encoding='latin1'))

# %% [markdown]
# #### Lists with the conditions following the structure of the data

# %%
strings=['DIR_CARTAS_C','DIR_CARTAS_NC', 'DIR_CUBILETES_C', 'DIR_CUBILETES_NC', 'DIR_MONEDAS_C', 'DIR_MONEDAS_NC', 'ORD_CARTAS_C', 'ORD_CARTAS_NC', 'ORD_CUBILETES_C', 'ORD_CUBILETES_NC', 'ORD_MONEDAS_C', 'ORD_MONEDAS_NC']
conditions=['d_c_c','d_c_n', 'd_b_c', 'd_b_n', 'd_m_c', 'd_m_n', 'o_c_c', 'o_c_n', 'o_b_c', 'o_b_n', 'o_m_c', 'o_m_n']
c_o_d=['directo', 'directo', 'directo', 'directo', 'directo', 'directo', 'video', 'video', 'video', 'video', 'video', 'video']
c_material=['cartas', 'cartas', 'cubiletes', 'cubiletes', 'monedas', 'monedas', 'cartas', 'cartas', 'cubiletes', 'cubiletes', 'monedas', 'monedas']
c_ncondi=['cond', 'no-cond', 'cond', 'no-cond', 'cond', 'no-cond', 'cond', 'no-cond', 'cond', 'no-cond', 'cond', 'no-cond']

subj_labels = strings_in=[[1,2,5,7,10,11,18,21,26,30,31,32,33,34,39,44,45,51], [3,4,6,8,9,12,13,16,17,22,25,40,41,42,43,46,47,52], [1,2,5,7,11,18,21,26,30,31,32,33,34,39,44,45,51], [3,4,6,8,9,12,13,16,17,22,25,40,41,42,43,46,47,52], [3,4,6,8,9,12,13,16,17,22,25,40,41,42,43,46,47,52], [1,2,5,7,10,11,18,21,26,30,31,32,33,34,39,44,45,51], [14,19,23,28,29,35,38,49,53], [15,20,24,27,36,37,48,50], [15,20,24,27,36,37,48,50], [14,19,23,28,29,35,38,49,53], [15,20,24,27,36,37,48,50], [14,19,23,28,29,35,38,49,53]]
#
label_channel =[ [str(i) + '_s_t', str(i) + '_s_740', str(i) + '_s_860', str(i) + '_l_t', str(i) + '_l_740', str(i) + '_l_860'] for i in range(0,16)]
label_channel = list(itertools.chain.from_iterable(label_channel)) 
colum_matrix = ['time', 'marks', 'baseline'] + label_channel

# %% [markdown]
# ### Create the DataFrame
# #### You substract the biseline value --> Your measure will be increase over the baseline in absolute terms
# #### You take the last 15 seconds of baseline
# #### You add regressors depending on vison (directo/ordenador), naturaluidad, etc...

# %%
frames=[]
for c_idx, cond in enumerate(conditions):
    subj_list = subj_labels[c_idx]
    for idx, subject in enumerate(subj_list):
        ### fataframe of this subject in this condition
        df_s = pd.DataFrame( data[c_idx][idx] )
        df_s.columns = colum_matrix
        ######
        ######
        ######
        ######        
        #### substract_baseline in each subject and condition
        #### (if you do not want this you have to comment)
        # baseline of each channel (when ==1)
        bl_column_mean = df_s.loc[df_s['baseline'] == 1].iloc[-150:].mean(axis=0)
        bl_column_std = df_s.loc[df_s['baseline'] == 1].iloc[-150:].std(axis=0)
        ## df of just recording ==2
        df_2 = df_s.loc[df_s['baseline'] == 2]
        #relative increase over baseline
        #_df_s = (df_2[label_channel] - bl_column_mean[label_channel])/ bl_column_std 
        df_s = df_2[label_channel] - bl_column_mean[label_channel]
        # this columns are the same
        df_s['time'] = df_2['time']
        df_s['marks'] = df_2['marks']   
        df_s['baseline'] = df_2['baseline']
        ######
        ######
        ######
        ######
        # add the subject and the condition (you need this inependently of the baseline substraction)
        df_s['cond'] = cond
        df_s['vision'] = c_o_d[c_idx]
        df_s['material'] = c_material[c_idx]
        df_s['naturalidad'] = c_ncondi[c_idx]
        df_s['subj'] = subject
        frames.append(df_s)
    

df_bl = pd.concat(frames, ignore_index=True)

# %%
df_bl
# Out:
#            0_s_t   0_s_740   0_s_860     0_l_t   0_l_740   0_l_860     1_s_t  \
# 0       0.000262  0.000549  0.001749  0.000262  0.000267 -0.001249  0.000355
# 1      -0.000638 -0.000151 -0.000551 -0.000638  0.001667  0.001151 -0.000245
# 2      -0.001838  0.001549  0.001649 -0.001838 -0.000133  0.001251  0.000555
# 3       0.000862  0.002349  0.007849  0.000862 -0.000333  0.003051 -0.000645
# 4       0.001162  0.004949  0.012749  0.001162  0.002167  0.004751 -0.001045
# 5      -0.001838  0.007649  0.018649 -0.001838  0.002167  0.006251  0.000555
# 6      -0.000538  0.009349  0.024049 -0.000538  0.003167  0.006951  0.000055
# 7      -0.000138  0.005449  0.011349 -0.000138  0.001667  0.001451  0.001055
# 8       0.000262 -0.000951 -0.004451  0.000262  0.000367  0.000351 -0.000845
# 9      -0.000238  0.000449 -0.001551 -0.000238  0.001067 -0.001849 -0.000445
# 10      0.000662  0.002749  0.006149  0.000662  0.000067  0.000851 -0.000645
# 11     -0.000838  0.006549  0.015549 -0.000838  0.000867  0.002751 -0.000245
# 12     -0.000838  0.001949  0.004549 -0.000838 -0.001633 -0.002549  0.000855
# 13     -0.000138 -0.004951 -0.011351 -0.000138 -0.001933 -0.004449 -0.000745
# 14     -0.000038 -0.003451 -0.007951 -0.000038 -0.001333 -0.004249  0.000855
# 15     -0.000038 -0.002451 -0.005151 -0.000038 -0.000733 -0.002449 -0.001245
# 16     -0.000438  0.001949  0.001449 -0.000438 -0.001233 -0.000749  0.001755
# 17     -0.001338  0.003149  0.008049 -0.001338  0.000667  0.001651  0.001555
# 18     -0.001338  0.003149  0.008049 -0.001338  0.000667  0.001651  0.001555
# 19      0.000562  0.012449  0.027149  0.000562  0.002167  0.002451 -0.000045
# 20     -0.001638  0.001949  0.004249 -0.001638 -0.000733 -0.003849  0.001055
# 21     -0.001638  0.001949  0.004249 -0.001638 -0.000733 -0.003849  0.001055
# 5            2.0  d_c_c  directo    cartas         cond     1
# 6            2.0  d_c_c  directo    cartas         cond     1
# 7            2.0  d_c_c  directo    cartas         cond     1
# 8            2.0  d_c_c  directo    cartas         cond     1
# 9            2.0  d_c_c  directo    cartas         cond     1
# 10           2.0  d_c_c  directo    cartas         cond     1
# 11           2.0  d_c_c  directo    cartas         cond     1
# 12           2.0  d_c_c  directo    cartas         cond     1
# 13           2.0  d_c_c  directo    cartas         cond     1
# 14           2.0  d_c_c  directo    cartas         cond     1
# 15           2.0  d_c_c  directo    cartas         cond     1
# 16           2.0  d_c_c  directo    cartas         cond     1
# 17           2.0  d_c_c  directo    cartas         cond     1
# 18           2.0  d_c_c  directo    cartas         cond     1
# 19           2.0  d_c_c  directo    cartas         cond     1
# 20           2.0  d_c_c  directo    cartas         cond     1
# 21           2.0  d_c_c  directo    cartas         cond     1
# 22           2.0  d_c_c  directo    cartas         cond     1
# 23           2.0  d_c_c  directo    cartas         cond     1
# 24           2.0  d_c_c  directo    cartas         cond     1
# 25           2.0  d_c_c  directo    cartas         cond     1
# 26           2.0  d_c_c  directo    cartas         cond     1
# 27           2.0  d_c_c  directo    cartas         cond     1
# 28           2.0  d_c_c  directo    cartas         cond     1
# 29           2.0  d_c_c  directo    cartas         cond     1
# ...          ...    ...      ...       ...          ...   ...
# 213932       2.0  o_m_n    video   monedas      no-cond    53
# 213933       2.0  o_m_n    video   monedas      no-cond    53
# 213934       2.0  o_m_n    video   monedas      no-cond    53
# 213935       2.0  o_m_n    video   monedas      no-cond    53
# 213936       2.0  o_m_n    video   monedas      no-cond    53
# 213937       2.0  o_m_n    video   monedas      no-cond    53
# 213938       2.0  o_m_n    video   monedas      no-cond    53
# 213939       2.0  o_m_n    video   monedas      no-cond    53
# 213940       2.0  o_m_n    video   monedas      no-cond    53
# 213941       2.0  o_m_n    video   monedas      no-cond    53
# 213942       2.0  o_m_n    video   monedas      no-cond    53
# 213943       2.0  o_m_n    video   monedas      no-cond    53
# 213944       2.0  o_m_n    video   monedas      no-cond    53
# 213945       2.0  o_m_n    video   monedas      no-cond    53
# 213946       2.0  o_m_n    video   monedas      no-cond    53
# 213947       2.0  o_m_n    video   monedas      no-cond    53
# 213948       2.0  o_m_n    video   monedas      no-cond    53
# 213949       2.0  o_m_n    video   monedas      no-cond    53
# 213950       2.0  o_m_n    video   monedas      no-cond    53
# 213951       2.0  o_m_n    video   monedas      no-cond    53
# 213952       2.0  o_m_n    video   monedas      no-cond    53
# 213953       2.0  o_m_n    video   monedas      no-cond    53
# 213954       2.0  o_m_n    video   monedas      no-cond    53
# 213955       2.0  o_m_n    video   monedas      no-cond    53
# 213956       2.0  o_m_n    video   monedas      no-cond    53
# 213957       2.0  o_m_n    video   monedas      no-cond    53
# 213958       2.0  o_m_n    video   monedas      no-cond    53
# 213959       2.0  o_m_n    video   monedas      no-cond    53
# 213960       2.0  o_m_n    video   monedas      no-cond    53
# 213961       2.0  o_m_n    video   monedas      no-cond    53
#
# [213962 rows x 104 columns]

# %% [markdown]
# ### Select the SURPRISE time in the df
# #### mark == 17 (there are others but I am 100% sure about this one, is the first time they press)
# #### As the channels can work differently, Y take 3 seconds before and 3 seconds after they press

# %%
##### df of 5 seconds after they click of surprise!
surprise_idx = df_bl.loc[df_bl['marks']==17].index
time_adquisition=10 # 10 frames for second


###plt.plot(df_bl[label_channel_t[8]].iloc[idx-150: idx+25])
t_b = 0
t_a = 30

df_5s=[]
for idx in surprise_idx:
    #df_before_mean =  df_bl.iloc[idx- t_base : idx ][label_channel].mean(axis=0)
    #df_before_std =  df_bl.iloc[idx- t_base : idx ][label_channel].std(axis=0)
    #df_after =  df_bl.iloc[idx-t_res : idx][label_channel] - df_before_mean
    df_after =  df_bl.iloc[idx-t_b : idx + t_a][label_channel] 
    df_after['cond'] = df_bl.iloc[idx-t_b : idx + t_a]['cond']
    df_after['vision'] = df_bl.iloc[idx-t_b : idx + t_a]['vision']
    df_after['material'] = df_bl.iloc[idx-t_b : idx+ t_a]['material']
    df_after['baseline'] = df_bl.iloc[idx-t_b : idx+ t_a]['baseline']
    df_after['naturalidad'] = df_bl.iloc[idx-t_b : idx+ t_a]['naturalidad']
    df_after['subj'] = df_bl.iloc[idx-t_b : idx+ t_a]['subj']
    df_5s.append( df_after ) ## df_bl.iloc[idx-50 : idx + 50]

        
##### 5 seconds after they click, normalized by baseline!
df_5s = pd.concat(df_5s, ignore_index=True)

# %% [markdown]
# #### Labels of the channels (for the plots)

# %%
label_channel_s_740 =[ str(i) + '_s_740' for i in range(0,16)] 
label_channel_l_740 =[ str(i) + '_l_740' for i in range(0,16)] 
label_channel_s_860 =[ str(i) + '_s_860' for i in range(0,16)] 
label_channel_l_860 =[ str(i) + '_l_860' for i in range(0,16)] 
label_channel_s_t =[ str(i) + '_s_t' for i in range(0,16)] 
label_channel_l_t =[ str(i) + '_l_t' for i in range(0,16)] 


## Plot to see the channels activity (after you run the following cell)
# for i in range(0,16):
#     plt.plot(df_bl[label_channel_s_740[i]].iloc[idx-150: idx+25], 'b')
#     plt.plot(df_bl[label_channel_l_740[i]].iloc[idx-150: idx+25], 'g')
#     plt.plot(df_bl[label_channel_s_860[i]].iloc[idx-150: idx+25], 'r')
#     plt.plot(df_bl[label_channel_l_860[i]].iloc[idx-150: idx+25], 'k')
#     plt.show()

# %% [markdown]
# ### Short distance of the channel
# #### The substracton 860 - 740  reflect the ncrease of oxigenation in the vascularization (HbO - Hbdesox)
#
# ### Plot the comparisions

# %%
#### Naturalidad
df_5s_nat = pd.melt(df_5s, id_vars='naturalidad', value_vars =label_channel_s_740 )
   
#### Material
df_5s_mat = pd.melt(df_5s, id_vars='material', value_vars =label_channel_s_740 )

#### visionado
df_5s_vis = pd.melt(df_5s, id_vars='vision', value_vars =label_channel_s_740 )

### all together in df_5
df_5s_subj = pd.melt(df_5s, id_vars='subj', value_vars =label_channel_s_740 )
df_5s_860 = pd.melt(df_5s, id_vars='naturalidad', value_vars =label_channel_s_860 ) 
## 860 - 740 to analyze!
value = df_5s_860['value'] - df_5s_vis['value']
df_5 = df_5s_vis.copy()
df_5['value'] = value
df_5['material'] = df_5s_mat['material']
df_5['naturalidad'] = df_5s_nat['naturalidad']
df_5['subj'] = df_5s_subj['subj']

######################### Plots ##############################

sns.factorplot(x='naturalidad', y='value', data=df_5, kind='bar' )
plt.title('Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', data=df_5, kind='bar' )
plt.title('material')
plt.show(block=False)

sns.factorplot(x='vision', y='value', data=df_5, kind='bar' )
plt.title('vision')
plt.show(block=False)

######

sns.factorplot(x='vision', y='value', hue='naturalidad', data=df_5, kind='bar' )
plt.title('Vision & Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', hue='naturalidad', data=df_5, kind='bar' )
plt.title('Material & Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', hue='vision', data=df_5, kind='bar' )
plt.title('Material & Vision')
plt.show(block=False)
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Long distance of the channel
# #### The substracton 860 - 740  reflect the ncrease of oxigenation in PFC (HbO - Hbdesox)
#
# ### Plot the comparisions

# %%
#### Naturalidad
df_5s_nat = pd.melt(df_5s, id_vars='naturalidad', value_vars =label_channel_l_740 )
   
#### Material
df_5s_mat = pd.melt(df_5s, id_vars='material', value_vars =label_channel_l_740 )

#### visionado
df_5s_vis = pd.melt(df_5s, id_vars='vision', value_vars =label_channel_l_740 )

### all together in df_5
df_5s_subj = pd.melt(df_5s, id_vars='subj', value_vars =label_channel_l_740 )
df_5s_860 = pd.melt(df_5s, id_vars='naturalidad', value_vars =label_channel_l_860 ) 
## 860 - 740 to analyze!
value = df_5s_860['value'] - df_5s_vis['value']
df_5_l = df_5s_vis.copy()
df_5_l['value'] = value
df_5_l['material'] = df_5s_mat['material']
df_5_l['naturalidad'] = df_5s_nat['naturalidad']
df_5_l['subj'] = df_5s_subj['subj']

######################### Plots ##############################

sns.factorplot(x='naturalidad', y='value', data=df_5_l, kind='bar' )
plt.title('Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', data=df_5_l, kind='bar' )
plt.title('material')
plt.show(block=False)

sns.factorplot(x='vision', y='value', data=df_5_l, kind='bar' )
plt.title('vision')
plt.show(block=False)

######

sns.factorplot(x='vision', y='value', hue='naturalidad', data=df_5_l, kind='bar' )
plt.title('Vision & Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', hue='naturalidad', data=df_5_l, kind='bar' )
plt.title('Material & Naturalidad')
plt.show(block=False)

sns.factorplot(x='material', y='value', hue='vision', data=df_5_l, kind='bar' )
plt.title('Material & Vision')
plt.show(block=False)
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
from linares_plot import *

# %%
df_5_l.loc[(df_5_l['subj']==2) & (df_5_l['material']=='cartas') & (df_5_l['variable']=='0_l_740')]
# Out:
#      vision variable     value material naturalidad  subj
# 0   directo  0_l_740  0.000112   cartas        cond     2
# 1   directo  0_l_740  0.000112   cartas        cond     2
# 2   directo  0_l_740  0.000112   cartas        cond     2
# 3   directo  0_l_740  0.000912   cartas        cond     2
# 4   directo  0_l_740  0.000812   cartas        cond     2
# 5   directo  0_l_740  0.000812   cartas        cond     2
# 6   directo  0_l_740  0.001012   cartas        cond     2
# 7   directo  0_l_740 -0.000388   cartas        cond     2
# 8   directo  0_l_740 -0.000388   cartas        cond     2
# 9   directo  0_l_740  0.000012   cartas        cond     2
# 10  directo  0_l_740 -0.001088   cartas        cond     2
# 11  directo  0_l_740  0.003312   cartas        cond     2
# 12  directo  0_l_740 -0.000888   cartas        cond     2
# 13  directo  0_l_740 -0.000088   cartas        cond     2
# 14  directo  0_l_740  0.000712   cartas        cond     2
# 15  directo  0_l_740  0.000112   cartas        cond     2
# 16  directo  0_l_740 -0.000188   cartas        cond     2
# 17  directo  0_l_740  0.000512   cartas        cond     2
# 18  directo  0_l_740  0.000312   cartas        cond     2
# 19  directo  0_l_740 -0.000688   cartas        cond     2
# 20  directo  0_l_740  0.001212   cartas        cond     2
# 21  directo  0_l_740  0.002212   cartas        cond     2
# 22  directo  0_l_740  0.004812   cartas        cond     2
# 23  directo  0_l_740  0.002012   cartas        cond     2
# 24  directo  0_l_740  0.002412   cartas        cond     2
# 25  directo  0_l_740  0.002412   cartas        cond     2
# 26  directo  0_l_740  0.002612   cartas        cond     2
# 27  directo  0_l_740  0.000512   cartas        cond     2
# 28  directo  0_l_740  0.000612   cartas        cond     2
# 29  directo  0_l_740  0.003912   cartas        cond     2

# %%
linares_plot(x='vision', y='value', df=df_5_l, palette='tab10', order=['directo', 'video'],  
             point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01, 0.015)
plt.show()
plt.title('Vision')
res_m = smf.ols(formula='value ~ vision', data=df_5_l, groups=df_5_l['subj']).fit()
print(res_m.summary())

# %%
linares_plot(x='vision', y='value', df=df_5_l, palette='tab10', order=['directo', 'video'], hue='naturalidad', 
             hue_order=['cond', 'no-cond'], point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Vision & Naturalidad')
res_m = smf.mixedlm(formula='value ~ vision*naturalidad', data=df_5_l, groups=df_5_l['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                     MixedLM         Dependent Variable:         value
# No. Observations:          112800          Method:                     REML
# No. Groups:                53              Scale:                      0.0003
# Min. group size:           480             Likelihood:                 298401.3686
# Max. group size:           4800            Converged:                  Yes
# Mean group size:           2128.3
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                               0.003    0.001   3.979 0.000  0.002  0.005
# vision[T.video]                        -0.002    0.001  -1.245 0.213 -0.005  0.001
# naturalidad[T.no-cond]                 -0.002    0.000 -17.984 0.000 -0.003 -0.002
# vision[T.video]:naturalidad[T.no-cond]  0.001    0.000   5.148 0.000  0.001  0.002
# Group Var                               0.000    0.000
# ==================================================================================

# %%
linares_plot(x='material', y='value', df=df_5_l, palette='viridis', order=['cartas', 'monedas', 'cubiletes'],  hue='naturalidad', 
             hue_order=['cond', 'no-cond'], point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Material&Naturalidad')
res_m = smf.mixedlm(formula='value ~ material*naturalidad', data=df_5_l, groups=df_5_l['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                          Mixed Linear Model Regression Results
# ========================================================================================
# Model:                       MixedLM           Dependent Variable:           value
# No. Observations:            112800            Method:                       REML
# No. Groups:                  53                Scale:                        0.0003
# Min. group size:             480               Likelihood:                   298626.7809
# Max. group size:             4800              Converged:                    Yes
# Mean group size:             2128.3
# ----------------------------------------------------------------------------------------
#                                              Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                     0.003    0.001   3.450 0.001  0.001  0.004
# material[T.cubiletes]                         0.001    0.000   2.577 0.010  0.000  0.001
# material[T.monedas]                           0.000    0.000   1.001 0.317 -0.000  0.001
# naturalidad[T.no-cond]                        0.002    0.000   4.965 0.000  0.001  0.002
# material[T.cubiletes]:naturalidad[T.no-cond] -0.003    0.000  -8.809 0.000 -0.004 -0.002
# material[T.monedas]:naturalidad[T.no-cond]   -0.006    0.000 -11.343 0.000 -0.007 -0.005
# Group Var                                     0.000    0.000
# ========================================================================================

# %%
linares_plot(x='material', y='value', df=df_5_l, palette='tab10', order=['cartas', 'monedas', 'cubiletes'], 
             point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Material')
res_m = smf.mixedlm(formula='value ~ material', data=df_5_l, groups=df_5_l['subj']).fit()
print(res_m.summary())

# %%
linares_plot(x='vision', y='value', df=df_5_l.loc[df_5_l['material']=='cartas'], palette='Blues', order=['directo', 'video'], hue='naturalidad', 
             hue_order=['cond', 'no-cond'], point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Vision & Naturalidad: Cartas')
plt.show()
res_m = smf.mixedlm(formula='value ~ vision*naturalidad', data=df_5_l.loc[df_5_l['material']=='cartas'], groups=df_5_l.loc[df_5_l['material']=='cartas']['subj']).fit()
print(res_m.summary())
res_m = smf.mixedlm(formula='value ~ vision+naturalidad', data=df_5_l.loc[df_5_l['material']=='cartas'], groups=df_5_l.loc[df_5_l['material']=='cartas']['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                     MixedLM         Dependent Variable:         value
# No. Observations:          23040           Method:                     REML
# No. Groups:                47              Scale:                      0.0001
# Min. group size:           480             Likelihood:                 71370.0193
# Max. group size:           960             Converged:                  Yes
# Mean group size:           490.2
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                               0.005    0.001  4.316 0.000  0.003  0.007
# vision[T.video]                        -0.001    0.002 -0.752 0.452 -0.005  0.002
# naturalidad[T.no-cond]                 -0.000    0.002 -0.212 0.832 -0.003  0.003
# vision[T.video]:naturalidad[T.no-cond] -0.004    0.003 -1.502 0.133 -0.009  0.001
# Group Var                               0.000    0.000
# =================================================================================
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#               Mixed Linear Model Regression Results
# =================================================================
# Model:               MixedLM    Dependent Variable:    value
# No. Observations:    23040      Method:                REML
# No. Groups:          47         Scale:                 0.0001
# Min. group size:     480        Likelihood:            71373.9145
# Max. group size:     960        Converged:             No
# Mean group size:     490.2
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.005    0.001  5.329 0.000  0.003  0.007
# vision[T.video]        -0.003    0.001 -2.362 0.018 -0.006 -0.001
# naturalidad[T.no-cond] -0.002    0.001 -1.319 0.187 -0.004  0.001
# Group Var               0.000    0.000
# =================================================================
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2026: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
linares_plot(x='vision', y='value', df=df_5_l.loc[df_5_l['material']=='monedas'], palette='Oranges', order=['directo', 'video'], hue='naturalidad', 
             hue_order=['cond', 'no-cond'], point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Vision & Naturalidad: Monedas')
plt.show()
res_m = smf.mixedlm(formula='value ~ vision*naturalidad', data=df_5_l.loc[df_5_l['material']=='monedas'], groups=df_5_l.loc[df_5_l['material']=='monedas']['subj']).fit()
print(res_m.summary())
res_m = smf.mixedlm(formula='value ~ vision+naturalidad', data=df_5_l.loc[df_5_l['material']=='monedas'], groups=df_5_l.loc[df_5_l['material']=='monedas']['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                    MixedLM         Dependent Variable:         value
# No. Observations:         54720           Method:                     REML
# No. Groups:               50              Scale:                      0.0003
# Min. group size:          480             Likelihood:                 144927.9348
# Max. group size:          1920            Converged:                  Yes
# Mean group size:          1094.4
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                               0.001    0.001  1.088 0.277 -0.001  0.004
# vision[T.video]                        -0.000    0.003 -0.049 0.961 -0.005  0.005
# naturalidad[T.no-cond]                 -0.001    0.002 -0.736 0.462 -0.005  0.002
# vision[T.video]:naturalidad[T.no-cond]  0.000    0.003  0.108 0.914 -0.006  0.007
# Group Var                               0.000    0.000
# =================================================================================
#
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                MixedLM   Dependent Variable:   value
# No. Observations:     54720     Method:               REML
# No. Groups:           50        Scale:                0.0003
# Min. group size:      480       Likelihood:           144932.7001
# Max. group size:      1920      Converged:            Yes
# Mean group size:      1094.4
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.001    0.001  1.151 0.250 -0.001  0.004
# vision[T.video]         0.000    0.002  0.046 0.963 -0.003  0.003
# naturalidad[T.no-cond] -0.001    0.002 -0.826 0.409 -0.004  0.002
# Group Var               0.000    0.000
# =================================================================
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
linares_plot(x='vision', y='value', df=df_5_l.loc[df_5_l['material']=='cubiletes'], palette='Greens', order=['directo', 'video'], hue='naturalidad', 
             hue_order=['cond', 'no-cond'], point_size=7, alpha=0.4, width=0.6, statistic=np.mean, by_subj=True, 
             subj_col='subj')
plt.ylim(-0.01,0.02);
plt.title('Vision & Naturalidad: cubiletes')
plt.show()
res_m = smf.mixedlm(formula='value ~ vision*naturalidad', data=df_5_l.loc[df_5_l['material']=='cubiletes'], groups=df_5_l.loc[df_5_l['material']=='cubiletes']['subj']).fit()
print(res_m.summary())
res_m = smf.mixedlm(formula='value ~ vision+naturalidad', data=df_5_l.loc[df_5_l['material']=='cubiletes'], groups=df_5_l.loc[df_5_l['material']=='cubiletes']['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2026: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                     MixedLM         Dependent Variable:         value
# No. Observations:          35040           Method:                     REML
# No. Groups:                52              Scale:                      0.0004
# Min. group size:           480             Likelihood:                 88739.5259
# Max. group size:           2400            Converged:                  No
# Mean group size:           673.8
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                               0.002    0.002  0.871 0.384 -0.003  0.007
# vision[T.video]                        -0.002    0.004 -0.565 0.572 -0.011  0.006
# naturalidad[T.no-cond]                 -0.001    0.003 -0.285 0.776 -0.008  0.006
# vision[T.video]:naturalidad[T.no-cond]  0.004    0.006  0.721 0.471 -0.008  0.016
# Group Var                               0.000    0.002
# =================================================================================
#
#               Mixed Linear Model Regression Results
# =================================================================
# Model:               MixedLM    Dependent Variable:    value
# No. Observations:    35040      Method:                REML
# No. Groups:          52         Scale:                 0.0004
# Min. group size:     480        Likelihood:            88745.9834
# Max. group size:     2400       Converged:             Yes
# Mean group size:     673.8
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.001    0.002  0.810 0.418 -0.002  0.005
# vision[T.video]        -0.000    0.002 -0.082 0.934 -0.005  0.004
# naturalidad[T.no-cond]  0.000    0.002  0.197 0.844 -0.004  0.005
# Group Var               0.000    0.001
# =================================================================
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
res_m = smf.mixedlm(formula='value ~ vision*naturalidad*material', data=df_5_l, groups=df_5_l['subj']).fit()
print(res_m.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                                  Mixed Linear Model Regression Results
# =======================================================================================================
# Model:                            MixedLM                Dependent Variable:                value
# No. Observations:                 112800                 Method:                            REML
# No. Groups:                       53                     Scale:                             0.0003
# Min. group size:                  480                    Likelihood:                        298637.7248
# Max. group size:                  4800                   Converged:                         Yes
# Mean group size:                  2128.3
# -------------------------------------------------------------------------------------------------------
#                                                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                                                     0.004    0.001  3.630 0.000  0.002  0.007
# vision[T.video]                                              -0.001    0.002 -0.494 0.621 -0.005  0.003
# naturalidad[T.no-cond]                                       -0.000    0.002 -0.149 0.882 -0.004  0.003
# material[T.cubiletes]                                         0.000    0.000  0.942 0.346 -0.000  0.001
# material[T.monedas]                                          -0.002    0.002 -1.475 0.140 -0.006  0.001
# vision[T.video]:naturalidad[T.no-cond]                       -0.003    0.003 -1.185 0.236 -0.009  0.002
# vision[T.video]:material[T.cubiletes]                        -0.004    0.002 -1.722 0.085 -0.009  0.001
# vision[T.video]:material[T.monedas]                          -0.001    0.003 -0.189 0.850 -0.006  0.005
# naturalidad[T.no-cond]:material[T.cubiletes]                 -0.003    0.000 -8.365 0.000 -0.004 -0.002
# naturalidad[T.no-cond]:material[T.monedas]                   -0.002    0.003 -0.577 0.564 -0.008  0.005
# vision[T.video]:naturalidad[T.no-cond]:material[T.cubiletes]  0.010    0.005  2.153 0.031  0.001  0.020
# vision[T.video]:naturalidad[T.no-cond]:material[T.monedas]    0.006    0.006  1.083 0.279 -0.005  0.018
# Group Var                                                     0.000    0.000
# =======================================================================================================
